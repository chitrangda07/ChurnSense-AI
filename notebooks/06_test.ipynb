# %%
import pandas as pd

# %%
df = pd.read_csv("../results/model_comparison.csv")
df.head()
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score  ROC AUC
# 0  Logistic Regression    0.8076     0.6728  0.5378    0.5978   0.8534
# 1        Decision Tree    0.7660     0.5681  0.5000    0.5317   0.7147
# 2        Random Forest    0.7790     0.5656  0.7264    0.6360   0.8477
# 3              XGBoost    0.7771     0.5598  0.7545    0.6427   0.8507
# 4             LightGBM    0.7646     0.5393  0.7846    0.6392   0.8519
